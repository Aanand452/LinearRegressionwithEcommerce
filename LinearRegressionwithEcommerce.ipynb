# %% [markdown]
# # THE MAIN AIM OF THIS PROJECT HOW MUCH MONEY CUSTOMER ANUALLY SPENDING THROUGH ECOMMERCE WEBSITE USING LINEAR REGRESSION MODEL

# %% [markdown]
# # Import Dependencices

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Download the ecommerce dataframe from the kaggle

# %%
df = pd.read_csv("/Users/apple/Downloads/Ecommerce Customers")

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
df.isna().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %% [markdown]
# # EDA

# %%
sns.jointplot(df,x="Avg. Session Length",y="Yearly Amount Spent",alpha=0.4)

# %%
sns.jointplot(df,x="Time on App",y="Yearly Amount Spent",alpha=0.4)

# %%
sns.jointplot(df,x="Time on Website",y="Yearly Amount Spent",alpha=0.5)

# %%
sns.jointplot(df,x="Length of Membership",y="Yearly Amount Spent",alpha=0.4)

# %%
sns.pairplot(df,kind='scatter',plot_kws={'alpha':0.4})

# %%
sns.lmplot(x="Length of Membership",y="Yearly Amount Spent",data=df,scatter_kws={'alpha':0.4})

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[["Avg. Session Length", "Time on App", "Time on Website", "Length of Membership"]]
y = df["Yearly Amount Spent"]

# %%
X
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
y
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
#           ...
# 495    573.847438
# 496    529.049004
# 497    551.620145
# 498    456.469510
# 499    497.778642
# Name: Yearly Amount Spent, Length: 500, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %% [markdown]
# # Training The Model

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 227            31.948017    13.085357        37.605653              2.648597
# 417            32.215527    12.216855        36.953960              2.910531
# 203            31.047222    11.199661        38.688709              3.088764
# 126            32.657269    11.957923        36.634652              4.106055
# 329            32.837893    13.185181        35.921595              1.823595
# ..                   ...          ...              ...                   ...
# 106            32.291756    12.190474        36.152462              3.781823
# 270            34.006489    12.956277        38.655095              3.275734
# 348            31.812483    10.886921        34.897828              3.128639
# 435            32.259973    14.132893        37.023479              3.762070
# 102            32.425697    11.448902        37.580190              2.586968
#
# [375 rows x 4 columns]

# %%
X_test
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 361            32.077590    10.347877        39.045156              3.434560
# 73             32.808698    12.817113        37.031539              3.851579
# 374            31.447446    10.101632        38.043453              4.238296
# 155            32.449522    13.457725        37.238806              2.941411
# 104            31.389585    10.994224        38.074452              3.428860
# ..                   ...          ...              ...                   ...
# 220            34.117567    11.591872        37.743620              3.678589
# 176            32.332637    11.548761        38.576516              4.773503
# 320            32.495419    12.968326        38.296110              1.200484
# 153            31.945396    12.965761        36.966389              6.076654
# 231            34.173752    12.144749        37.258031              3.397363
#
# [125 rows x 4 columns]

# %%
y_train
# Out:
# 227    461.920877
# 417    438.417742
# 203    392.497399
# 126    516.831557
# 329    445.062186
#           ...
# 106    494.551861
# 270    540.995739
# 348    392.810345
# 435    571.216005
# 102    420.737673
# Name: Yearly Amount Spent, Length: 375, dtype: float64

# %%
y_test
# Out:
# 361    401.033135
# 73     534.777188
# 374    418.602742
# 155    503.978379
# 104    410.069611
#           ...
# 220    519.372977
# 176    532.717486
# 320    368.654785
# 153    657.019924
# 231    512.552534
# Name: Yearly Amount Spent, Length: 125, dtype: float64

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([25.69083176, 38.68815596,  0.45279908, 61.71050259])

# %%
cdf = pd.DataFrame(lm.coef_,X.columns,columns=['Coef'])

# %%
cdf
# Out:
#                            Coef
# Avg. Session Length   25.690832
# Time on App           38.688156
# Time on Website        0.452799
# Length of Membership  61.710503

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([403.36087526, 542.49652255, 426.79061944, 501.98000522,
#        409.90016607, 569.95203575, 531.68712688, 506.10842617,
#        408.47031037, 473.71493101, 441.30201774, 425.05268133,
#        424.93655583, 527.27340348, 431.24084639, 423.76635768,
#        575.73837263, 484.73375076, 458.15131382, 481.73089746,
#        502.04156769, 513.39008852, 507.55579577, 646.54871994,
#        449.98886069, 496.07689142, 556.2403381 , 554.77842999,
#        399.41536028, 325.54121912, 532.65563818, 477.96272707,
#        500.87585571, 305.69578623, 505.5581936 , 483.59198597,
#        518.72294437, 437.96539568, 456.5172541 , 470.84325957,
#        494.20975196, 445.1840947 , 508.62394573, 500.91793768,
#        488.73418105, 535.19202701, 595.04122136, 513.81284729,
#        280.44329112, 433.04560196, 421.42401729, 481.13163584,
#        584.63530063, 608.71467973, 564.01947373, 494.49273084,
#        394.32484472, 456.44102533, 572.84643521, 499.46263062,
# ...

# %%
sns.scatterplot(x=predictions, y=y_test)
plt.xlabel("predictions")
plt.ylabel("Yearly Amount Spent")
# Out:
# Text(0, 0.5, 'Yearly Amount Spent')

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
import math

# %%
print("Mean Absolute Error:",mean_absolute_error(y_test,predictions))
print("Mean Squred Error:",mean_squared_error(y_test,predictions))
print("RMSE:", math.sqrt(mean_squared_error(y_test,predictions)))
# Out:
# Mean Absolute Error: 8.460454170141144
# Mean Squred Error: 105.64514296279467
# RMSE: 10.278382312542897

# %% [markdown]
# # Residuals

# %%
residuals = y_test - predictions

# %%
residuals
# Out:
# 361    -2.327740
# 73     -7.719334
# 374    -8.187877
# 155     1.998374
# 104     0.169445
#          ...
# 220     1.005683
# 176    -6.070432
# 320    -8.615673
# 153    -6.329575
# 231   -11.073503
# Name: Yearly Amount Spent, Length: 125, dtype: float64

# %%
sns.displot(residuals,bins=30,kde=True)

# %%
import pylab
import scipy.stats as stats
stats.probplot(residuals,dist="norm",plot=pylab)
pylab.show()
